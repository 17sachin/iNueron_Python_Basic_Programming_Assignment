# %% [markdown]
# <a href="https://colab.research.google.com/github/17sachin/iNueron_Python_Basic_Programming_Assignment/blob/main/Programming_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.Write a Python program to check if a number is Positive , Negative or Zero?

# %%
a=int(input("Enter a number :"))
if a > 0:
  print("Number is Positive")
if a==0:
  print("Number is Zero")
else:
  print("Number is Negative")
# Out:
# Enter a number :-45
# Number is Negative

# %% [markdown]
# 2.Write a Python program to check if a number is Odd or Even?

# %%
a=int(input("Enter a number :"))
if a%2==0:
  print("Number is Even")
else:
  print("Number is odd")
# Out:
# Enter a number :99
# Number is odd

# %% [markdown]
# 3.Write a Python program to check Leap year?

# %%
import calendar

yy=int(input("Enter the Year :"))
if yy%4==0:
  print("Year is Leap")
else:
  print("Year is not Leap")
# Out:
# Enter the Year :2020
# Year is Leap

# %% [markdown]
# 4.Write a Python program to Check Prime Number?

# %%
num=int(input("Enter a Number :"))

if num > 1:
  for i in range(2,num):
    if num%i==0:
      print("Number is not a Prime :",num)
      break
    else:
      print("Number is Prime:",num)
# Out:
# Enter a Number :4
# Number is not a Prime : 4

# %% [markdown]
# 5.Write a Python program to Print all Prime Numbers in an Interval of 1-10000?

# %%
lower=1
upper=10000

for num in range(lower,upper+1):
  if num > 1:
    for i in range(2,num):
      if num%i==0:
        print("Number is not a Prime :",num)
        break
    else:
      print("Number is Prime:",num)
# Out:
# Streaming output truncated to the last 5000 lines.
# Number is not a Prime : 5001
# Number is not a Prime : 5002
# Number is Prime: 5003
# Number is not a Prime : 5004
# Number is not a Prime : 5005
# Number is not a Prime : 5006
# Number is not a Prime : 5007
# Number is not a Prime : 5008
# Number is Prime: 5009
# Number is not a Prime : 5010
# Number is Prime: 5011
# Number is not a Prime : 5012
# Number is not a Prime : 5013
# Number is not a Prime : 5014
# Number is not a Prime : 5015
# Number is not a Prime : 5016
# Number is not a Prime : 5017
# Number is not a Prime : 5018
# Number is not a Prime : 5019
# Number is not a Prime : 5020
# Number is Prime: 5021
# Number is not a Prime : 5022
# Number is Prime: 5023
# Number is not a Prime : 5024
# Number is not a Prime : 5025
# Number is not a Prime : 5026
# Number is not a Prime : 5027
# Number is not a Prime : 5028
# Number is not a Prime : 5029
# Number is not a Prime : 5030
# Number is not a Prime : 5031
# ...
